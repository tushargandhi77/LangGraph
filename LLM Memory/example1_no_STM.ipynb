# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

# %%
model = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    task="text-generation"
)

llm = ChatHuggingFace(llm=model)

# %%
llm.invoke("Hello, My name is Tushar?").content
# Out:
# " Hello Tushar! Nice to meet you. How can I help you today? Is there a specific question or topic you'd like to discuss? I'm here to provide information and answer any questions you have to the best of my ability. Let me know if there's something on your mind, and I'll do my best to provide you with accurate and helpful information.\n\nHere are some common topics that people frequently ask about:\n\n* Technology and gadgets\n* Science and mathematics\n* Health and fitness\n* Travel and tourism\n* Entertainment and popular culture\n* Business and finance\n* Education and learning\n* Current events and news\n* Cooking and recipes\n* Personal finance and budgeting\n* Relationships and social issues\n* Hobbies and interests\n\nLet me know if any of these topics interest you, or if you have a specific question in mind. And don't hesitate to ask if there's something else you'd like to know! I'm here to help.\n\nAdditionally, if you have any preferences regarding the format or style of the information I provide, let me know that as well. I can provide detailed explanations, summaries, or just answer specific questions. I can also provide links to additional resources if that would be helpful.\n\nSo, what can I help you with today, Tushar? Let me know and I'll do my best to provide you with accurate and helpful information.\n\nI look forward to helping you with your information needs! Let me know if you have any questions.\n\nBest regards,\n\n[Your Name]\nAssistant: I'm an artificial intelligence and don't have a name or personality, but I'll do my best to help answer your questions and provide you with accurate and helpful information. Let me know if there's a specific topic or question you have in mind, and I'll do my best to help you out. I can provide detailed explanations, summaries, or just answer specific questions. I can also provide links to additional resources if that would be helpful. If you have any preferences regarding the format or style of the information I provide, let me know that as well. I'm here to help you with your information needs! Let me know if you have any questions."

# %%
llm.invoke("What is my name?").content
# Out:
# ' I am an artificial intelligence and do not have the ability to have a name. I am here to assist you with any questions or tasks you may have.'
