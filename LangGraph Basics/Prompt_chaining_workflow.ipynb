# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
load_dotenv()
# Out:
# True

# %%
# create a LLM model instance
model = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    # fetch title
    title = state['title']

    # call  llm gen outline
    prompt = f"Generate a detailed outline for a blog on the topic - {title} in 30 words."
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f"Write a detailed blog on the topic {title} using the following outline \n {outline} in 100 words "

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog', END)

# create workflow
workflow = graph.compile()

# %%
initial_state = {'title': "Rise of the AI in india"}

final_state = workflow.invoke(initial_state)

print(final_state['content'])
# Out:
# ## Blog: The AI Awakening: India's Journey to Becoming a Global AI Powerhouse
#
# **I. Introduction: Setting the Stage for AI's Growth in India**
#
# **A. Hook:** Imagine a world where AI-powered drones monitor crops, optimizing irrigation and fertilizer use for millions of smallholder farmers. Or picture AI tutors personalizing education for every child, regardless of their background or location. This isn't science fiction; it's the burgeoning reality of Artificial Intelligence in India, a country poised to redefine its future through the power of intelligent machines.
#
# **B. Briefly Define AI:** Artificial Intelligence (AI) is essentially the ability of computers to mimic human intelligence. This includes tasks like learning from data, solving problems, recognizing patterns, and making decisions – all without explicit programming for each specific scenario.
#
# ...
